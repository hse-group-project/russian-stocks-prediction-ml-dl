# %%
import os
import logging
from datetime import timedelta, datetime

from tinkoff.invest import CandleInterval, Client, SecurityTradingStatus
from tinkoff.invest.schemas import CandleSource
from tinkoff.invest.services import InstrumentsService
from tinkoff.invest.utils import now, quotation_to_decimal
from pandas import DataFrame

import asyncio
import pandas as pd
import requests
from sqlalchemy import create_engine, TIMESTAMP
from sqlalchemy.exc import SQLAlchemyError
from sqlalchemy import text
from pprint import pprint

# %%
TOKEN=""

# %%
with Client(TOKEN) as client:
    account_info = client.users.get_accounts().accounts[0]
    pprint(account_info)
# Out:
# Account(id='2171778018',
#         type=<AccountType.ACCOUNT_TYPE_TINKOFF: 1>,
#         name='Брокерский счёт',
#         status=<AccountStatus.ACCOUNT_STATUS_OPEN: 2>,
#         opened_date=datetime.datetime(2022, 5, 10, 0, 0, tzinfo=datetime.timezone.utc),
#         closed_date=datetime.datetime(1970, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#         access_level=<AccessLevel.ACCOUNT_ACCESS_LEVEL_READ_ONLY: 2>)

# %%
top_50_companies = ['SBER', 'SBERP', 'ROSN', 'LKOH', 'GAZP', 'NVTK', 'SIBN', 'PLZL', 'GMKN', 'TATN', 'YDEX', 'SNGS', 'SNGSP', 'CHMF',
                    'MGNT', 'NLMK', 'VTBR', 'AFLT', 'PIKK', 'MOEX', 'SIBN', 'NVTK', 'PLZL', 'GMKN', 'TATN',	'SNGS', 'YDEX',
                    'TRNF', 'CHMF',	'VTBR',	'PHOR',	'NLMK',	'AKRN', 'FIVE',	'OZON', 'RUAL', 'T', 'MGNT', 'MOEX',
                    'IRAO', 'MAGN', 'ALRS', 'MTSS', 'BANE',	'CBOM', 'SVCB', 'VSMO', 'PIKK', 'POLY', 'IRKT',
                    'HYDR', 'HEAD', 'AFLT', 'FLOT', 'AGRO', 'ENPG', 'UNAC', 'RTKM', 'GCHE', 'ROSB', 'RASP',
                    'NKNC', 'SFIN', 'NMTP', 'BSPB', 'FEES', 'FIXP', 'POSI', 'UWGN', 'KZOS', 'UGLD', 'KUBE', 'FESH']

# %%
tickers = [
    "SBER", "GAZP", "X5", "PIKK", "PLZL", "LKOH", "GMKN", "VTBR", "NVTK",
    "YDEX", "TATN", "SMLT", "SPBE", "ROSN", "AFLT", "IRAO", "VKCO", "CHMF",
    "NLMK", "MAGN", "MGNT", "MTLR", "AFKS", "MOEX", "POSI", "ALRS", "BELU",
    "MTSS", "SVCB", "SNGS", "HEAD", "CNRU", "PHOR", "RTKM", "SIBN", "UGLD",
    "RUAL", "HYDR", "BSPB", "FEES", "EUTR", "RNFT", "MRKC", "MDMG", "FLOT",
    "UPRO", "ASTR", "IVAT", "LENT", "WUSH", "UWGN", "ENPG", "TRMK", "MVID",
    "RASP", "RAGR", "MRKP", "SVAV", "AQUA", "RENI", "SOFL", "SGZH", "SFIN",
    "OZPH", "NMTP", "FIXR", "OGKB", "SELG", "LEAS", "CBOM", "VSMO", "IRKT",
    "VSEH"
]

# %%
len(tickers)
# Out:
# 73

# %%
def main():
    with Client(TOKEN) as client:
        for candle in client.get_all_candles(
            instrument_id="BBG004730N88",
            from_=now() - timedelta(days=365),
            interval=CandleInterval.CANDLE_INTERVAL_HOUR,
            candle_source_type=CandleSource.CANDLE_SOURCE_UNSPECIFIED,
        ):
            print(candle)

    return 0

# %%
main()
# Out:
# HistoricCandle(open=Quotation(units=243, nano=210000000), high=Quotation(units=243, nano=870000000), low=Quotation(units=243, nano=90000000), close=Quotation(units=243, nano=450000000), volume=865340, time=datetime.datetime(2024, 10, 29, 17, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=243, nano=450000000), high=Quotation(units=243, nano=920000000), low=Quotation(units=243, nano=420000000), close=Quotation(units=243, nano=680000000), volume=634120, time=datetime.datetime(2024, 10, 29, 18, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=243, nano=680000000), high=Quotation(units=243, nano=950000000), low=Quotation(units=243, nano=0), close=Quotation(units=243, nano=0), volume=707360, time=datetime.datetime(2024, 10, 29, 19, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=243, nano=10000000), high=Quotation(units=243, nano=170000000), low=Quotation(units=242, nano=220000000), close=Quotation(units=242, nano=660000000), volume=975410, time=datetime.datetime(2024, 10, 29, 20, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=243, nano=620000000), high=Quotation(units=244, nano=500000000), low=Quotation(units=241, nano=100000000), close=Quotation(units=243, nano=660000000), volume=31650, time=datetime.datetime(2024, 10, 30, 4, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=243, nano=660000000), high=Quotation(units=243, nano=950000000), low=Quotation(units=243, nano=520000000), close=Quotation(units=243, nano=690000000), volume=26200, time=datetime.datetime(2024, 10, 30, 5, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=243, nano=550000000), high=Quotation(units=243, nano=730000000), low=Quotation(units=242, nano=700000000), close=Quotation(units=242, nano=700000000), volume=135480, time=datetime.datetime(2024, 10, 30, 6, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=242, nano=860000000), high=Quotation(units=245, nano=480000000), low=Quotation(units=241, nano=770000000), close=Quotation(units=245, nano=390000000), volume=9228320, time=datetime.datetime(2024, 10, 30, 7, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=245, nano=390000000), high=Quotation(units=246, nano=190000000), low=Quotation(units=244, nano=860000000), close=Quotation(units=245, nano=250000000), volume=5404630, time=datetime.datetime(2024, 10, 30, 8, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=245, nano=260000000), high=Quotation(units=246, nano=220000000), low=Quotation(units=245, nano=30000000), close=Quotation(units=245, nano=130000000), volume=2747010, time=datetime.datetime(2024, 10, 30, 9, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=245, nano=140000000), high=Quotation(units=245, nano=220000000), low=Quotation(units=244, nano=210000000), close=Quotation(units=244, nano=690000000), volume=2091990, time=datetime.datetime(2024, 10, 30, 10, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=244, nano=680000000), high=Quotation(units=244, nano=820000000), low=Quotation(units=243, nano=220000000), close=Quotation(units=243, nano=340000000), volume=2405500, time=datetime.datetime(2024, 10, 30, 11, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=243, nano=330000000), high=Quotation(units=244, nano=400000000), low=Quotation(units=243, nano=90000000), close=Quotation(units=243, nano=910000000), volume=2713020, time=datetime.datetime(2024, 10, 30, 12, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=243, nano=920000000), high=Quotation(units=244, nano=150000000), low=Quotation(units=242, nano=660000000), close=Quotation(units=243, nano=500000000), volume=1920360, time=datetime.datetime(2024, 10, 30, 13, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=243, nano=520000000), high=Quotation(units=244, nano=950000000), low=Quotation(units=243, nano=440000000), close=Quotation(units=244, nano=450000000), volume=2114850, time=datetime.datetime(2024, 10, 30, 14, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=244, nano=450000000), high=Quotation(units=245, nano=100000000), low=Quotation(units=244, nano=120000000), close=Quotation(units=245, nano=100000000), volume=2231270, time=datetime.datetime(2024, 10, 30, 15, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=244, nano=400000000), high=Quotation(units=244, nano=590000000), low=Quotation(units=243, nano=250000000), close=Quotation(units=243, nano=780000000), volume=2450290, time=datetime.datetime(2024, 10, 30, 16, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=243, nano=780000000), high=Quotation(units=244, nano=70000000), low=Quotation(units=242, nano=870000000), close=Quotation(units=242, nano=910000000), volume=1475610, time=datetime.datetime(2024, 10, 30, 17, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=242, nano=910000000), high=Quotation(units=243, nano=470000000), low=Quotation(units=242, nano=220000000), close=Quotation(units=242, nano=680000000), volume=1736290, time=datetime.datetime(2024, 10, 30, 18, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=242, nano=660000000), high=Quotation(units=243, nano=220000000), low=Quotation(units=242, nano=100000000), close=Quotation(units=242, nano=160000000), volume=1318850, time=datetime.datetime(2024, 10, 30, 19, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=242, nano=150000000), high=Quotation(units=242, nano=510000000), low=Quotation(units=241, nano=110000000), close=Quotation(units=241, nano=450000000), volume=1877150, time=datetime.datetime(2024, 10, 30, 20, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=241, nano=620000000), high=Quotation(units=242, nano=920000000), low=Quotation(units=240, nano=360000000), close=Quotation(units=242, nano=70000000), volume=59560, time=datetime.datetime(2024, 10, 31, 4, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=242, nano=70000000), high=Quotation(units=242, nano=500000000), low=Quotation(units=241, nano=320000000), close=Quotation(units=241, nano=970000000), volume=47060, time=datetime.datetime(2024, 10, 31, 5, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=241, nano=900000000), high=Quotation(units=241, nano=910000000), low=Quotation(units=241, nano=200000000), close=Quotation(units=241, nano=400000000), volume=338620, time=datetime.datetime(2024, 10, 31, 6, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=241, nano=390000000), high=Quotation(units=242, nano=800000000), low=Quotation(units=240, nano=0), close=Quotation(units=242, nano=170000000), volume=9191180, time=datetime.datetime(2024, 10, 31, 7, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=242, nano=170000000), high=Quotation(units=242, nano=740000000), low=Quotation(units=241, nano=110000000), close=Quotation(units=241, nano=380000000), volume=3932110, time=datetime.datetime(2024, 10, 31, 8, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=241, nano=390000000), high=Quotation(units=241, nano=780000000), low=Quotation(units=238, nano=330000000), close=Quotation(units=239, nano=580000000), volume=12271260, time=datetime.datetime(2024, 10, 31, 9, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=239, nano=580000000), high=Quotation(units=241, nano=0), low=Quotation(units=239, nano=20000000), close=Quotation(units=240, nano=730000000), volume=4462880, time=datetime.datetime(2024, 10, 31, 10, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=240, nano=750000000), high=Quotation(units=241, nano=990000000), low=Quotation(units=239, nano=10000000), close=Quotation(units=241, nano=400000000), volume=5307630, time=datetime.datetime(2024, 10, 31, 11, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=241, nano=390000000), high=Quotation(units=241, nano=520000000), low=Quotation(units=240, nano=300000000), close=Quotation(units=240, nano=540000000), volume=1315070, time=datetime.datetime(2024, 10, 31, 12, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=240, nano=510000000), high=Quotation(units=240, nano=900000000), low=Quotation(units=239, nano=30000000), close=Quotation(units=239, nano=350000000), volume=2928710, time=datetime.datetime(2024, 10, 31, 13, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=239, nano=350000000), high=Quotation(units=239, nano=920000000), low=Quotation(units=238, nano=330000000), close=Quotation(units=239, nano=0), volume=4393920, time=datetime.datetime(2024, 10, 31, 14, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=239, nano=10000000), high=Quotation(units=239, nano=790000000), low=Quotation(units=238, nano=880000000), close=Quotation(units=239, nano=260000000), volume=2007150, time=datetime.datetime(2024, 10, 31, 15, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=239, nano=250000000), high=Quotation(units=239, nano=260000000), low=Quotation(units=237, nano=750000000), close=Quotation(units=238, nano=250000000), volume=3235760, time=datetime.datetime(2024, 10, 31, 16, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=238, nano=270000000), high=Quotation(units=238, nano=350000000), low=Quotation(units=236, nano=230000000), close=Quotation(units=236, nano=380000000), volume=3250050, time=datetime.datetime(2024, 10, 31, 17, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=236, nano=350000000), high=Quotation(units=237, nano=750000000), low=Quotation(units=236, nano=300000000), close=Quotation(units=237, nano=750000000), volume=2264050, time=datetime.datetime(2024, 10, 31, 18, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=237, nano=750000000), high=Quotation(units=237, nano=920000000), low=Quotation(units=236, nano=800000000), close=Quotation(units=237, nano=600000000), volume=1579530, time=datetime.datetime(2024, 10, 31, 19, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=237, nano=600000000), high=Quotation(units=238, nano=200000000), low=Quotation(units=237, nano=570000000), close=Quotation(units=237, nano=900000000), volume=872880, time=datetime.datetime(2024, 10, 31, 20, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=237, nano=300000000), high=Quotation(units=238, nano=940000000), low=Quotation(units=237, nano=20000000), close=Quotation(units=238, nano=350000000), volume=32370, time=datetime.datetime(2024, 11, 1, 4, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=238, nano=110000000), high=Quotation(units=238, nano=310000000), low=Quotation(units=237, nano=600000000), close=Quotation(units=237, nano=800000000), volume=49030, time=datetime.datetime(2024, 11, 1, 5, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=237, nano=800000000), high=Quotation(units=238, nano=190000000), low=Quotation(units=237, nano=620000000), close=Quotation(units=237, nano=900000000), volume=76680, time=datetime.datetime(2024, 11, 1, 6, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=237, nano=910000000), high=Quotation(units=239, nano=100000000), low=Quotation(units=237, nano=100000000), close=Quotation(units=237, nano=340000000), volume=5950470, time=datetime.datetime(2024, 11, 1, 7, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=237, nano=340000000), high=Quotation(units=237, nano=700000000), low=Quotation(units=235, nano=10000000), close=Quotation(units=236, nano=250000000), volume=10779080, time=datetime.datetime(2024, 11, 1, 8, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=236, nano=240000000), high=Quotation(units=236, nano=250000000), low=Quotation(units=234, nano=570000000), close=Quotation(units=235, nano=60000000), volume=6240840, time=datetime.datetime(2024, 11, 1, 9, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=235, nano=70000000), high=Quotation(units=236, nano=190000000), low=Quotation(units=234, nano=830000000), close=Quotation(units=235, nano=80000000), volume=3359240, time=datetime.datetime(2024, 11, 1, 10, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=235, nano=120000000), high=Quotation(units=236, nano=450000000), low=Quotation(units=234, nano=900000000), close=Quotation(units=236, nano=50000000), volume=2980970, time=datetime.datetime(2024, 11, 1, 11, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=236, nano=30000000), high=Quotation(units=236, nano=210000000), low=Quotation(units=234, nano=610000000), close=Quotation(units=234, nano=950000000), volume=3002030, time=datetime.datetime(2024, 11, 1, 12, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=234, nano=950000000), high=Quotation(units=236, nano=500000000), low=Quotation(units=234, nano=900000000), close=Quotation(units=235, nano=950000000), volume=2521580, time=datetime.datetime(2024, 11, 1, 13, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=235, nano=950000000), high=Quotation(units=238, nano=500000000), low=Quotation(units=235, nano=900000000), close=Quotation(units=237, nano=200000000), volume=6225590, time=datetime.datetime(2024, 11, 1, 14, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=237, nano=190000000), high=Quotation(units=238, nano=390000000), low=Quotation(units=237, nano=0), close=Quotation(units=238, nano=160000000), volume=2443020, time=datetime.datetime(2024, 11, 1, 15, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=238, nano=200000000), high=Quotation(units=239, nano=0), low=Quotation(units=237, nano=870000000), close=Quotation(units=238, nano=110000000), volume=1696210, time=datetime.datetime(2024, 11, 1, 16, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=238, nano=100000000), high=Quotation(units=238, nano=990000000), low=Quotation(units=237, nano=30000000), close=Quotation(units=237, nano=300000000), volume=1845610, time=datetime.datetime(2024, 11, 1, 17, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=237, nano=300000000), high=Quotation(units=237, nano=570000000), low=Quotation(units=237, nano=200000000), close=Quotation(units=237, nano=360000000), volume=368700, time=datetime.datetime(2024, 11, 1, 18, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=237, nano=330000000), high=Quotation(units=237, nano=940000000), low=Quotation(units=237, nano=200000000), close=Quotation(units=237, nano=930000000), volume=448950, time=datetime.datetime(2024, 11, 1, 19, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=237, nano=900000000), high=Quotation(units=238, nano=50000000), low=Quotation(units=237, nano=510000000), close=Quotation(units=238, nano=30000000), volume=456240, time=datetime.datetime(2024, 11, 1, 20, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=237, nano=730000000), high=Quotation(units=239, nano=500000000), low=Quotation(units=237, nano=730000000), close=Quotation(units=238, nano=810000000), volume=37720, time=datetime.datetime(2024, 11, 2, 4, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=238, nano=630000000), high=Quotation(units=238, nano=820000000), low=Quotation(units=238, nano=500000000), close=Quotation(units=238, nano=800000000), volume=16210, time=datetime.datetime(2024, 11, 2, 5, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=238, nano=800000000), high=Quotation(units=238, nano=800000000), low=Quotation(units=237, nano=900000000), close=Quotation(units=237, nano=900000000), volume=57850, time=datetime.datetime(2024, 11, 2, 6, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=237, nano=880000000), high=Quotation(units=238, nano=950000000), low=Quotation(units=237, nano=880000000), close=Quotation(units=238, nano=450000000), volume=2216210, time=datetime.datetime(2024, 11, 2, 7, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=238, nano=460000000), high=Quotation(units=238, nano=600000000), low=Quotation(units=237, nano=710000000), close=Quotation(units=237, nano=940000000), volume=808130, time=datetime.datetime(2024, 11, 2, 8, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=237, nano=940000000), high=Quotation(units=238, nano=160000000), low=Quotation(units=237, nano=810000000), close=Quotation(units=238, nano=80000000), volume=539580, time=datetime.datetime(2024, 11, 2, 9, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=238, nano=70000000), high=Quotation(units=238, nano=700000000), low=Quotation(units=237, nano=970000000), close=Quotation(units=238, nano=460000000), volume=1000400, time=datetime.datetime(2024, 11, 2, 10, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=238, nano=460000000), high=Quotation(units=239, nano=340000000), low=Quotation(units=238, nano=460000000), close=Quotation(units=238, nano=900000000), volume=1549410, time=datetime.datetime(2024, 11, 2, 11, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=238, nano=900000000), high=Quotation(units=239, nano=440000000), low=Quotation(units=238, nano=710000000), close=Quotation(units=239, nano=260000000), volume=1559070, time=datetime.datetime(2024, 11, 2, 12, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=239, nano=270000000), high=Quotation(units=240, nano=0), low=Quotation(units=239, nano=20000000), close=Quotation(units=239, nano=840000000), volume=2186480, time=datetime.datetime(2024, 11, 2, 13, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=239, nano=850000000), high=Quotation(units=240, nano=0), low=Quotation(units=238, nano=460000000), close=Quotation(units=238, nano=660000000), volume=2482930, time=datetime.datetime(2024, 11, 2, 14, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=238, nano=640000000), high=Quotation(units=238, nano=990000000), low=Quotation(units=238, nano=490000000), close=Quotation(units=238, nano=930000000), volume=544590, time=datetime.datetime(2024, 11, 2, 15, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=238, nano=880000000), high=Quotation(units=239, nano=170000000), low=Quotation(units=238, nano=500000000), close=Quotation(units=239, nano=90000000), volume=377650, time=datetime.datetime(2024, 11, 2, 16, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=239, nano=90000000), high=Quotation(units=239, nano=90000000), low=Quotation(units=238, nano=610000000), close=Quotation(units=238, nano=910000000), volume=462910, time=datetime.datetime(2024, 11, 2, 17, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=238, nano=910000000), high=Quotation(units=239, nano=300000000), low=Quotation(units=238, nano=890000000), close=Quotation(units=239, nano=100000000), volume=520280, time=datetime.datetime(2024, 11, 2, 18, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=239, nano=80000000), high=Quotation(units=239, nano=330000000), low=Quotation(units=238, nano=980000000), close=Quotation(units=239, nano=0), volume=289710, time=datetime.datetime(2024, 11, 2, 19, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=239, nano=0), high=Quotation(units=239, nano=170000000), low=Quotation(units=238, nano=960000000), close=Quotation(units=238, nano=970000000), volume=315840, time=datetime.datetime(2024, 11, 2, 20, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=239, nano=100000000), high=Quotation(units=239, nano=250000000), low=Quotation(units=238, nano=510000000), close=Quotation(units=239, nano=230000000), volume=4380, time=datetime.datetime(2024, 11, 3, 4, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=230000000), high=Quotation(units=239, nano=400000000), low=Quotation(units=238, nano=840000000), close=Quotation(units=239, nano=320000000), volume=10900, time=datetime.datetime(2024, 11, 3, 5, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=330000000), high=Quotation(units=239, nano=360000000), low=Quotation(units=238, nano=870000000), close=Quotation(units=239, nano=330000000), volume=11180, time=datetime.datetime(2024, 11, 3, 6, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=100000000), high=Quotation(units=239, nano=350000000), low=Quotation(units=239, nano=0), close=Quotation(units=239, nano=190000000), volume=12630, time=datetime.datetime(2024, 11, 3, 7, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=20000000), high=Quotation(units=239, nano=220000000), low=Quotation(units=239, nano=0), close=Quotation(units=239, nano=30000000), volume=9930, time=datetime.datetime(2024, 11, 3, 8, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=190000000), high=Quotation(units=239, nano=190000000), low=Quotation(units=238, nano=940000000), close=Quotation(units=239, nano=0), volume=14600, time=datetime.datetime(2024, 11, 3, 9, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=190000000), high=Quotation(units=239, nano=400000000), low=Quotation(units=238, nano=810000000), close=Quotation(units=239, nano=400000000), volume=23590, time=datetime.datetime(2024, 11, 3, 10, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=140000000), high=Quotation(units=239, nano=390000000), low=Quotation(units=239, nano=10000000), close=Quotation(units=239, nano=20000000), volume=11770, time=datetime.datetime(2024, 11, 3, 11, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=20000000), high=Quotation(units=239, nano=350000000), low=Quotation(units=239, nano=10000000), close=Quotation(units=239, nano=100000000), volume=10540, time=datetime.datetime(2024, 11, 3, 12, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=310000000), high=Quotation(units=239, nano=330000000), low=Quotation(units=239, nano=20000000), close=Quotation(units=239, nano=270000000), volume=8170, time=datetime.datetime(2024, 11, 3, 13, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=270000000), high=Quotation(units=239, nano=900000000), low=Quotation(units=238, nano=910000000), close=Quotation(units=239, nano=130000000), volume=24470, time=datetime.datetime(2024, 11, 3, 14, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=290000000), high=Quotation(units=241, nano=450000000), low=Quotation(units=239, nano=50000000), close=Quotation(units=240, nano=300000000), volume=141210, time=datetime.datetime(2024, 11, 3, 15, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=240, nano=300000000), high=Quotation(units=240, nano=300000000), low=Quotation(units=239, nano=790000000), close=Quotation(units=239, nano=990000000), volume=33290, time=datetime.datetime(2024, 11, 3, 16, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=890000000), high=Quotation(units=239, nano=990000000), low=Quotation(units=239, nano=520000000), close=Quotation(units=239, nano=780000000), volume=20630, time=datetime.datetime(2024, 11, 3, 17, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=780000000), high=Quotation(units=239, nano=780000000), low=Quotation(units=239, nano=340000000), close=Quotation(units=239, nano=600000000), volume=33970, time=datetime.datetime(2024, 11, 3, 18, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=600000000), high=Quotation(units=239, nano=910000000), low=Quotation(units=239, nano=340000000), close=Quotation(units=239, nano=400000000), volume=26310, time=datetime.datetime(2024, 11, 3, 19, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=610000000), high=Quotation(units=239, nano=990000000), low=Quotation(units=239, nano=240000000), close=Quotation(units=239, nano=410000000), volume=14210, time=datetime.datetime(2024, 11, 3, 20, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=238, nano=560000000), high=Quotation(units=240, nano=30000000), low=Quotation(units=238, nano=560000000), close=Quotation(units=240, nano=20000000), volume=7060, time=datetime.datetime(2024, 11, 4, 4, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=240, nano=20000000), high=Quotation(units=240, nano=30000000), low=Quotation(units=239, nano=650000000), close=Quotation(units=239, nano=890000000), volume=12270, time=datetime.datetime(2024, 11, 4, 5, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=890000000), high=Quotation(units=240, nano=200000000), low=Quotation(units=239, nano=700000000), close=Quotation(units=240, nano=50000000), volume=19930, time=datetime.datetime(2024, 11, 4, 6, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=240, nano=50000000), high=Quotation(units=240, nano=150000000), low=Quotation(units=239, nano=800000000), close=Quotation(units=240, nano=0), volume=16870, time=datetime.datetime(2024, 11, 4, 7, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=900000000), high=Quotation(units=240, nano=0), low=Quotation(units=239, nano=330000000), close=Quotation(units=239, nano=950000000), volume=52860, time=datetime.datetime(2024, 11, 4, 8, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=950000000), high=Quotation(units=239, nano=950000000), low=Quotation(units=239, nano=580000000), close=Quotation(units=239, nano=890000000), volume=18450, time=datetime.datetime(2024, 11, 4, 9, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=890000000), high=Quotation(units=239, nano=980000000), low=Quotation(units=239, nano=590000000), close=Quotation(units=239, nano=930000000), volume=21180, time=datetime.datetime(2024, 11, 4, 10, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=930000000), high=Quotation(units=239, nano=960000000), low=Quotation(units=239, nano=620000000), close=Quotation(units=239, nano=960000000), volume=16800, time=datetime.datetime(2024, 11, 4, 11, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=960000000), high=Quotation(units=239, nano=970000000), low=Quotation(units=239, nano=640000000), close=Quotation(units=239, nano=970000000), volume=14320, time=datetime.datetime(2024, 11, 4, 12, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=810000000), high=Quotation(units=239, nano=990000000), low=Quotation(units=239, nano=640000000), close=Quotation(units=239, nano=940000000), volume=20020, time=datetime.datetime(2024, 11, 4, 13, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=940000000), high=Quotation(units=240, nano=0), low=Quotation(units=239, nano=640000000), close=Quotation(units=239, nano=980000000), volume=28910, time=datetime.datetime(2024, 11, 4, 14, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=990000000), high=Quotation(units=240, nano=0), low=Quotation(units=239, nano=770000000), close=Quotation(units=239, nano=990000000), volume=11350, time=datetime.datetime(2024, 11, 4, 15, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=990000000), high=Quotation(units=240, nano=0), low=Quotation(units=239, nano=640000000), close=Quotation(units=239, nano=660000000), volume=16390, time=datetime.datetime(2024, 11, 4, 16, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=870000000), high=Quotation(units=239, nano=980000000), low=Quotation(units=239, nano=640000000), close=Quotation(units=239, nano=680000000), volume=11710, time=datetime.datetime(2024, 11, 4, 17, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=950000000), high=Quotation(units=239, nano=990000000), low=Quotation(units=239, nano=680000000), close=Quotation(units=239, nano=970000000), volume=9830, time=datetime.datetime(2024, 11, 4, 18, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=720000000), high=Quotation(units=239, nano=980000000), low=Quotation(units=239, nano=710000000), close=Quotation(units=239, nano=730000000), volume=9790, time=datetime.datetime(2024, 11, 4, 19, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=730000000), high=Quotation(units=240, nano=200000000), low=Quotation(units=239, nano=690000000), close=Quotation(units=240, nano=170000000), volume=19200, time=datetime.datetime(2024, 11, 4, 20, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=700000000), high=Quotation(units=240, nano=710000000), low=Quotation(units=239, nano=700000000), close=Quotation(units=240, nano=220000000), volume=16800, time=datetime.datetime(2024, 11, 5, 4, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=240, nano=200000000), high=Quotation(units=240, nano=250000000), low=Quotation(units=239, nano=990000000), close=Quotation(units=240, nano=200000000), volume=19530, time=datetime.datetime(2024, 11, 5, 5, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=240, nano=200000000), high=Quotation(units=240, nano=200000000), low=Quotation(units=239, nano=600000000), close=Quotation(units=239, nano=600000000), volume=82840, time=datetime.datetime(2024, 11, 5, 6, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=239, nano=610000000), high=Quotation(units=241, nano=200000000), low=Quotation(units=239, nano=140000000), close=Quotation(units=239, nano=770000000), volume=6978910, time=datetime.datetime(2024, 11, 5, 7, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=239, nano=770000000), high=Quotation(units=240, nano=330000000), low=Quotation(units=238, nano=750000000), close=Quotation(units=239, nano=920000000), volume=3864150, time=datetime.datetime(2024, 11, 5, 8, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=239, nano=920000000), high=Quotation(units=240, nano=960000000), low=Quotation(units=239, nano=630000000), close=Quotation(units=240, nano=800000000), volume=2244130, time=datetime.datetime(2024, 11, 5, 9, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=240, nano=800000000), high=Quotation(units=241, nano=110000000), low=Quotation(units=240, nano=330000000), close=Quotation(units=240, nano=460000000), volume=2173050, time=datetime.datetime(2024, 11, 5, 10, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=240, nano=400000000), high=Quotation(units=240, nano=700000000), low=Quotation(units=239, nano=730000000), close=Quotation(units=240, nano=150000000), volume=1650650, time=datetime.datetime(2024, 11, 5, 11, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=240, nano=140000000), high=Quotation(units=240, nano=510000000), low=Quotation(units=239, nano=810000000), close=Quotation(units=240, nano=140000000), volume=1175430, time=datetime.datetime(2024, 11, 5, 12, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=240, nano=130000000), high=Quotation(units=240, nano=430000000), low=Quotation(units=239, nano=160000000), close=Quotation(units=239, nano=610000000), volume=1669530, time=datetime.datetime(2024, 11, 5, 13, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=239, nano=580000000), high=Quotation(units=239, nano=750000000), low=Quotation(units=238, nano=70000000), close=Quotation(units=239, nano=270000000), volume=3371730, time=datetime.datetime(2024, 11, 5, 14, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=239, nano=270000000), high=Quotation(units=239, nano=620000000), low=Quotation(units=238, nano=730000000), close=Quotation(units=239, nano=230000000), volume=930590, time=datetime.datetime(2024, 11, 5, 15, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=239, nano=490000000), high=Quotation(units=240, nano=270000000), low=Quotation(units=239, nano=10000000), close=Quotation(units=240, nano=140000000), volume=1688760, time=datetime.datetime(2024, 11, 5, 16, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=240, nano=140000000), high=Quotation(units=240, nano=190000000), low=Quotation(units=238, nano=930000000), close=Quotation(units=239, nano=120000000), volume=804560, time=datetime.datetime(2024, 11, 5, 17, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=239, nano=130000000), high=Quotation(units=239, nano=730000000), low=Quotation(units=238, nano=550000000), close=Quotation(units=238, nano=840000000), volume=880150, time=datetime.datetime(2024, 11, 5, 18, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=238, nano=840000000), high=Quotation(units=239, nano=70000000), low=Quotation(units=238, nano=730000000), close=Quotation(units=238, nano=910000000), volume=368780, time=datetime.datetime(2024, 11, 5, 19, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=238, nano=900000000), high=Quotation(units=239, nano=280000000), low=Quotation(units=238, nano=850000000), close=Quotation(units=239, nano=230000000), volume=308540, time=datetime.datetime(2024, 11, 5, 20, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=240, nano=920000000), high=Quotation(units=243, nano=580000000), low=Quotation(units=240, nano=920000000), close=Quotation(units=242, nano=800000000), volume=422730, time=datetime.datetime(2024, 11, 6, 4, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=242, nano=800000000), high=Quotation(units=245, nano=530000000), low=Quotation(units=242, nano=440000000), close=Quotation(units=245, nano=340000000), volume=474530, time=datetime.datetime(2024, 11, 6, 5, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=245, nano=340000000), high=Quotation(units=247, nano=0), low=Quotation(units=244, nano=570000000), close=Quotation(units=247, nano=0), volume=1733760, time=datetime.datetime(2024, 11, 6, 6, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_DEALER_WEEKEND: 2>)
# HistoricCandle(open=Quotation(units=247, nano=0), high=Quotation(units=248, nano=450000000), low=Quotation(units=244, nano=570000000), close=Quotation(units=246, nano=610000000), volume=26202810, time=datetime.datetime(2024, 11, 6, 7, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=246, nano=650000000), high=Quotation(units=248, nano=560000000), low=Quotation(units=246, nano=420000000), close=Quotation(units=247, nano=230000000), volume=12788300, time=datetime.datetime(2024, 11, 6, 8, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=247, nano=230000000), high=Quotation(units=248, nano=200000000), low=Quotation(units=246, nano=700000000), close=Quotation(units=246, nano=780000000), volume=6280160, time=datetime.datetime(2024, 11, 6, 9, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=246, nano=730000000), high=Quotation(units=246, nano=890000000), low=Quotation(units=244, nano=700000000), close=Quotation(units=245, nano=800000000), volume=7344340, time=datetime.datetime(2024, 11, 6, 10, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=245, nano=850000000), high=Quotation(units=246, nano=910000000), low=Quotation(units=244, nano=170000000), close=Quotation(units=245, nano=80000000), volume=4960980, time=datetime.datetime(2024, 11, 6, 11, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=245, nano=80000000), high=Quotation(units=245, nano=80000000), low=Quotation(units=243, nano=320000000), close=Quotation(units=243, nano=920000000), volume=6219770, time=datetime.datetime(2024, 11, 6, 12, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=243, nano=910000000), high=Quotation(units=244, nano=300000000), low=Quotation(units=242, nano=50000000), close=Quotation(units=243, nano=180000000), volume=5188260, time=datetime.datetime(2024, 11, 6, 13, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=243, nano=200000000), high=Quotation(units=244, nano=150000000), low=Quotation(units=242, nano=360000000), close=Quotation(units=243, nano=350000000), volume=2539430, time=datetime.datetime(2024, 11, 6, 14, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=243, nano=330000000), high=Quotation(units=244, nano=100000000), low=Quotation(units=243, nano=100000000), close=Quotation(units=243, nano=190000000), volume=1333230, time=datetime.datetime(2024, 11, 6, 15, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=243, nano=200000000), high=Quotation(units=243, nano=680000000), low=Quotation(units=242, nano=500000000), close=Quotation(units=243, nano=400000000), volume=1306120, time=datetime.datetime(2024, 11, 6, 16, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# ...
# HistoricCandle(open=Quotation(units=284, nano=150000000), high=Quotation(units=286, nano=220000000), low=Quotation(units=284, nano=130000000), close=Quotation(units=285, nano=700000000), volume=2014368, time=datetime.datetime(2025, 10, 27, 9, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=285, nano=690000000), high=Quotation(units=285, nano=840000000), low=Quotation(units=283, nano=550000000), close=Quotation(units=284, nano=310000000), volume=2107261, time=datetime.datetime(2025, 10, 27, 10, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=284, nano=310000000), high=Quotation(units=284, nano=730000000), low=Quotation(units=282, nano=560000000), close=Quotation(units=283, nano=450000000), volume=3715162, time=datetime.datetime(2025, 10, 27, 11, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=283, nano=450000000), high=Quotation(units=284, nano=350000000), low=Quotation(units=282, nano=940000000), close=Quotation(units=284, nano=10000000), volume=2515747, time=datetime.datetime(2025, 10, 27, 12, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=284, nano=20000000), high=Quotation(units=284, nano=200000000), low=Quotation(units=282, nano=460000000), close=Quotation(units=283, nano=200000000), volume=2454275, time=datetime.datetime(2025, 10, 27, 13, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=283, nano=200000000), high=Quotation(units=285, nano=420000000), low=Quotation(units=282, nano=940000000), close=Quotation(units=284, nano=710000000), volume=2800158, time=datetime.datetime(2025, 10, 27, 14, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=284, nano=750000000), high=Quotation(units=285, nano=200000000), low=Quotation(units=284, nano=120000000), close=Quotation(units=284, nano=400000000), volume=1272548, time=datetime.datetime(2025, 10, 27, 15, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=284, nano=400000000), high=Quotation(units=284, nano=790000000), low=Quotation(units=284, nano=280000000), close=Quotation(units=284, nano=630000000), volume=689592, time=datetime.datetime(2025, 10, 27, 16, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=284, nano=640000000), high=Quotation(units=284, nano=640000000), low=Quotation(units=283, nano=900000000), close=Quotation(units=284, nano=350000000), volume=573544, time=datetime.datetime(2025, 10, 27, 17, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=284, nano=360000000), high=Quotation(units=284, nano=400000000), low=Quotation(units=283, nano=700000000), close=Quotation(units=284, nano=230000000), volume=802362, time=datetime.datetime(2025, 10, 27, 18, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=284, nano=230000000), high=Quotation(units=284, nano=390000000), low=Quotation(units=283, nano=0), close=Quotation(units=284, nano=40000000), volume=756973, time=datetime.datetime(2025, 10, 27, 19, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=284, nano=40000000), high=Quotation(units=284, nano=40000000), low=Quotation(units=282, nano=470000000), close=Quotation(units=283, nano=170000000), volume=1342836, time=datetime.datetime(2025, 10, 27, 20, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=283, nano=220000000), high=Quotation(units=283, nano=220000000), low=Quotation(units=283, nano=220000000), close=Quotation(units=283, nano=220000000), volume=2778, time=datetime.datetime(2025, 10, 28, 3, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=283, nano=220000000), high=Quotation(units=283, nano=700000000), low=Quotation(units=281, nano=0), close=Quotation(units=283, nano=400000000), volume=2436169, time=datetime.datetime(2025, 10, 28, 4, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=283, nano=480000000), high=Quotation(units=284, nano=700000000), low=Quotation(units=283, nano=300000000), close=Quotation(units=284, nano=520000000), volume=1335115, time=datetime.datetime(2025, 10, 28, 5, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=284, nano=520000000), high=Quotation(units=286, nano=500000000), low=Quotation(units=284, nano=520000000), close=Quotation(units=285, nano=950000000), volume=3657464, time=datetime.datetime(2025, 10, 28, 6, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=286, nano=0), high=Quotation(units=286, nano=850000000), low=Quotation(units=285, nano=400000000), close=Quotation(units=286, nano=250000000), volume=2756219, time=datetime.datetime(2025, 10, 28, 7, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=286, nano=250000000), high=Quotation(units=288, nano=740000000), low=Quotation(units=286, nano=250000000), close=Quotation(units=288, nano=690000000), volume=5794904, time=datetime.datetime(2025, 10, 28, 8, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=288, nano=700000000), high=Quotation(units=289, nano=290000000), low=Quotation(units=288, nano=240000000), close=Quotation(units=288, nano=660000000), volume=3563520, time=datetime.datetime(2025, 10, 28, 9, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=288, nano=660000000), high=Quotation(units=288, nano=990000000), low=Quotation(units=287, nano=960000000), close=Quotation(units=288, nano=50000000), volume=1571878, time=datetime.datetime(2025, 10, 28, 10, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=288, nano=90000000), high=Quotation(units=289, nano=680000000), low=Quotation(units=288, nano=40000000), close=Quotation(units=289, nano=500000000), volume=3247528, time=datetime.datetime(2025, 10, 28, 11, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=289, nano=500000000), high=Quotation(units=290, nano=0), low=Quotation(units=288, nano=130000000), close=Quotation(units=288, nano=200000000), volume=1955819, time=datetime.datetime(2025, 10, 28, 12, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=288, nano=200000000), high=Quotation(units=289, nano=150000000), low=Quotation(units=287, nano=270000000), close=Quotation(units=289, nano=150000000), volume=3138267, time=datetime.datetime(2025, 10, 28, 13, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=289, nano=150000000), high=Quotation(units=290, nano=0), low=Quotation(units=288, nano=700000000), close=Quotation(units=289, nano=250000000), volume=1968730, time=datetime.datetime(2025, 10, 28, 14, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=289, nano=250000000), high=Quotation(units=289, nano=720000000), low=Quotation(units=288, nano=500000000), close=Quotation(units=288, nano=950000000), volume=1079463, time=datetime.datetime(2025, 10, 28, 15, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=288, nano=930000000), high=Quotation(units=289, nano=860000000), low=Quotation(units=288, nano=530000000), close=Quotation(units=289, nano=800000000), volume=1049405, time=datetime.datetime(2025, 10, 28, 16, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=289, nano=810000000), high=Quotation(units=290, nano=620000000), low=Quotation(units=289, nano=730000000), close=Quotation(units=290, nano=620000000), volume=1507410, time=datetime.datetime(2025, 10, 28, 17, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=290, nano=620000000), high=Quotation(units=290, nano=700000000), low=Quotation(units=289, nano=330000000), close=Quotation(units=289, nano=790000000), volume=875328, time=datetime.datetime(2025, 10, 28, 18, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=289, nano=800000000), high=Quotation(units=290, nano=400000000), low=Quotation(units=289, nano=370000000), close=Quotation(units=289, nano=720000000), volume=487557, time=datetime.datetime(2025, 10, 28, 19, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=289, nano=720000000), high=Quotation(units=289, nano=990000000), low=Quotation(units=288, nano=670000000), close=Quotation(units=289, nano=460000000), volume=539205, time=datetime.datetime(2025, 10, 28, 20, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=290, nano=450000000), high=Quotation(units=290, nano=450000000), low=Quotation(units=290, nano=450000000), close=Quotation(units=290, nano=450000000), volume=38209, time=datetime.datetime(2025, 10, 29, 3, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=290, nano=490000000), high=Quotation(units=290, nano=790000000), low=Quotation(units=289, nano=100000000), close=Quotation(units=290, nano=300000000), volume=842490, time=datetime.datetime(2025, 10, 29, 4, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=290, nano=370000000), high=Quotation(units=290, nano=700000000), low=Quotation(units=289, nano=650000000), close=Quotation(units=290, nano=90000000), volume=476961, time=datetime.datetime(2025, 10, 29, 5, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=290, nano=40000000), high=Quotation(units=290, nano=40000000), low=Quotation(units=288, nano=150000000), close=Quotation(units=288, nano=500000000), volume=1515323, time=datetime.datetime(2025, 10, 29, 6, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=288, nano=500000000), high=Quotation(units=290, nano=460000000), low=Quotation(units=288, nano=160000000), close=Quotation(units=290, nano=80000000), volume=3212900, time=datetime.datetime(2025, 10, 29, 7, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=290, nano=120000000), high=Quotation(units=290, nano=550000000), low=Quotation(units=289, nano=40000000), close=Quotation(units=289, nano=890000000), volume=1900840, time=datetime.datetime(2025, 10, 29, 8, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=289, nano=860000000), high=Quotation(units=290, nano=60000000), low=Quotation(units=289, nano=40000000), close=Quotation(units=289, nano=730000000), volume=1119164, time=datetime.datetime(2025, 10, 29, 9, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=289, nano=720000000), high=Quotation(units=290, nano=0), low=Quotation(units=289, nano=180000000), close=Quotation(units=289, nano=540000000), volume=921172, time=datetime.datetime(2025, 10, 29, 10, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=289, nano=540000000), high=Quotation(units=290, nano=560000000), low=Quotation(units=289, nano=40000000), close=Quotation(units=289, nano=480000000), volume=1664144, time=datetime.datetime(2025, 10, 29, 11, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=289, nano=490000000), high=Quotation(units=289, nano=960000000), low=Quotation(units=288, nano=750000000), close=Quotation(units=289, nano=430000000), volume=1459931, time=datetime.datetime(2025, 10, 29, 12, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=289, nano=390000000), high=Quotation(units=289, nano=690000000), low=Quotation(units=288, nano=780000000), close=Quotation(units=289, nano=530000000), volume=1687177, time=datetime.datetime(2025, 10, 29, 13, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=289, nano=520000000), high=Quotation(units=289, nano=840000000), low=Quotation(units=288, nano=960000000), close=Quotation(units=289, nano=510000000), volume=1130236, time=datetime.datetime(2025, 10, 29, 14, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=289, nano=510000000), high=Quotation(units=291, nano=400000000), low=Quotation(units=289, nano=500000000), close=Quotation(units=291, nano=400000000), volume=2754452, time=datetime.datetime(2025, 10, 29, 15, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=291, nano=330000000), high=Quotation(units=291, nano=510000000), low=Quotation(units=290, nano=700000000), close=Quotation(units=291, nano=0), volume=1117838, time=datetime.datetime(2025, 10, 29, 16, 0, tzinfo=datetime.timezone.utc), is_complete=True, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# HistoricCandle(open=Quotation(units=291, nano=0), high=Quotation(units=291, nano=40000000), low=Quotation(units=290, nano=760000000), close=Quotation(units=290, nano=800000000), volume=155579, time=datetime.datetime(2025, 10, 29, 17, 0, tzinfo=datetime.timezone.utc), is_complete=False, candle_source=<CandleSource.CANDLE_SOURCE_EXCHANGE: 1>)
# 0

# %%
def get_shares_info(token, tickers):
    with Client(token) as client:
        shares = client.instruments.shares()
        actual_shares = sorted([share_info for share_info in shares.instruments if share_info.country_of_risk == 'RU' and share_info.ticker in tickers], \
                            key = lambda x: tickers.index(x.ticker))

    shares_info = pd.DataFrame(columns=['figi', 'ticker', 'name', 'sector', 'first_1day_candle_date', 'first_1min_candle_date'])

    for share in actual_shares:
        shares_info.loc[len(shares_info)] = [share.figi, share.ticker, share.name, share.sector,
                                                pd.to_datetime(share.first_1day_candle_date).date(),
                                                pd.to_datetime(share.first_1min_candle_date).date()]
    
    return shares_info

# %%
shares_info = get_shares_info(TOKEN, tickers)

# %%
shares_info
# Out:
#             figi ticker                       name       sector  \
# 0   BBG004730N88   SBER                  Сбер Банк    financial
# 1   BBG004730RP0   GAZP                    Газпром       energy
# 2   TCS03A108X38     X5  Корпоративный Центр Икс 5     consumer
# 3   BBG004S68BH6   PIKK                        ПИК  real_estate
# 4   BBG000R607Y3   PLZL                      Полюс    materials
# ..           ...    ...                        ...          ...
# 68  TCS00A0ZZFS9   LEAS                   Европлан        other
# 69  BBG009GSYN76   CBOM                        МКБ
# 70  BBG004S68CV8   VSMO               ВСМПО-АВИСМА    materials
# 71  BBG000FWGSZ5   IRKT                    Яковлев  industrials
# 72  TCS10A108K09   VSEH                      ВИ.РУ     consumer
#
#    first_1day_candle_date first_1min_candle_date
# 0              2000-01-04             2018-03-07
# 1              2006-01-23             2018-03-07
# 2              2018-02-01             2018-03-07
# 3              2007-06-29             2018-03-07
# 4              2006-05-12             2018-03-07
# ..                    ...                    ...
# 68             2024-03-29             2024-03-29
# 69             2015-07-01             2018-03-07
# 70             2005-06-20             2018-03-07
# 71             2004-03-09             2018-03-07
# 72             2024-07-05             2024-07-05
#
# [73 rows x 6 columns]

# %%
def extract_data(token, shares_info, interval, to_time, from_time):

    shares_data = pd.DataFrame(columns=['ticker', 'time', 'open', 'high', 'low', 'close', 'volume'])

    with Client(token) as client:

        for share_figi in shares_info['figi']:
            share_candles = client.market_data.get_candles(
                instrument_id=share_figi,
                from_=from_time,
                to=to_time,
                interval=interval,
                candle_source_type=3
                )
            for share_candle in share_candles.candles:
                shares_data.loc[len(shares_data)] = [shares_info['ticker'][shares_info['figi'] == share_figi].values[0],
                                                     pd.to_datetime(share_candle.time), #.date()
                                                     float(str(share_candle.open.units) + '.' + str(share_candle.open.nano)),
                                                     float(str(share_candle.high.units) + '.' + str(share_candle.open.nano)),
                                                     float(str(share_candle.low.units) + '.' + str(share_candle.open.nano)),
                                                     float(str(share_candle.close.units) + '.' + str(share_candle.open.nano)),
                                                     share_candle.volume]
    return shares_data

# %%
interval = CandleInterval.CANDLE_INTERVAL_DAY

extract_data(TOKEN, 
             shares_info, 
             interval, 
             datetime.now() - timedelta(days=1), 
             datetime.now() - timedelta(days=1) - timedelta(days=12*30))
# Out:
#       ticker                      time    open    high     low   close  \
# 0       SBER 2024-11-02 00:00:00+00:00  237.90  240.90  237.90  238.90
# 1       SBER 2024-11-05 00:00:00+00:00  239.60  241.60  238.60  239.60
# 2       SBER 2024-11-06 00:00:00+00:00  247.00  248.00  242.00  243.00
# 3       SBER 2024-11-07 00:00:00+00:00  243.26  251.26  242.26  250.26
# 4       SBER 2024-11-08 00:00:00+00:00  251.50  255.50  250.50  255.50
# ...      ...                       ...     ...     ...     ...     ...
# 21654   VSEH 2025-10-22 00:00:00+00:00   64.14   65.14   63.14   63.14
# 21655   VSEH 2025-10-23 00:00:00+00:00   63.00   63.00   61.00   63.00
# 21656   VSEH 2025-10-24 00:00:00+00:00   63.10   63.10   62.10   62.10
# 21657   VSEH 2025-10-27 00:00:00+00:00   62.82   63.82   61.82   61.82
# 21658   VSEH 2025-10-28 00:00:00+00:00   61.36   61.36   60.36   61.36
#
#          volume
# 0      14895450
# 1      28172270
# 2      78965200
# 3      44425190
# 4      58086370
# ...         ...
# 21654    442326
# 21655    411772
# 21656    289329
# 21657    368962
# 21658    320592
#
# [21659 rows x 7 columns]
